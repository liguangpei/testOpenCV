# %% [markdown]
# # 3.1knn最近邻算法可用于分类和回归
# k的默认值是5

# %% [markdown]
# # 3.2K最近邻算法的应用

# %% [markdown]
# # # 3.2.1K最近邻算法在分类中的应用

# %%
#导入数据集生成器
from sklearn.datasets import make_blobs
#导入knn分类器
from sklearn.neighbors import KNeighborsClassifier
#导入画图工具
import matplotlib.pyplot as plt
#导入数据拆分工具
from sklearn.model_selection import train_test_split
# %matplotlib inline
#生成样本数为200，分类为2的数据集
data = make_blobs(n_samples=200, centers=2, random_state=8)
X,y=data
print(X.shape)
print(y.shape)
#将生成的数据集进行可视化显示
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.get_cmap('spring'), edgecolors='k')
#plt.show()
# Out:
# (200, 2)
# (200,)

# %%
import numpy as np
# %matplotlib inline
clf = KNeighborsClassifier()#此处必须加括号，否则会出现TypeError: fit() missing 1 required positional argument: 'y'
clf.fit(X,y)

#下面的代码用于画图
x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
y_min, y_max = X[:,1].min()-1, X[:, 1].max()+1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))
print(np.c_[xx.ravel(), yy.ravel()].shape)
z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
z = z.reshape(xx.shape)
plt.pcolormesh(xx, yy, z, cmap=plt.cm.get_cmap('Pastel1'))
plt.scatter(X[:,0], X[:, 1], c = y, cmap=plt.cm.get_cmap('spring'), edgecolors='k')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:KNN")

#把新的数据点用红五星表示
newpoint = [6.75, 4.82]
plt.scatter(newpoint[0],newpoint[1], marker='*', c='red', s=200)
#对新数据点分类进行判断
print('\n\n\n')
print('===============================================')
print('新数据点分类是:',clf.predict([newpoint]))
print('===============================================')
print('\n\n\n')
#plt.show()
# Out:
# (102723, 2)
#
#
#
#
# ===============================================
# 新数据点分类是: [1]
# ===============================================

# %% [markdown]
# # 3.2.2K最近邻算法处理多元分类

# %%
# %matplotlib inline
#生成样本数为200，分类为2的数据集
data = make_blobs(n_samples=500, centers=5, random_state=8)
X,y=data
print(X.shape)
print(y.shape)
#将生成的数据集进行可视化显示
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.get_cmap('spring'), edgecolors='k')
plt.show()
# Out:
# (500, 2)
# (500,)

# %%
# %matplotlib inline
clf = KNeighborsClassifier()#此处必须加括号，否则会出现TypeError: fit() missing 1 required positional argument: 'y'
clf.fit(X,y)

#下面的代码用于画图
x_min, x_max = X[:,0].min()-1, X[:,0].max()+1
y_min, y_max = X[:,1].min()-1, X[:, 1].max()+1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))
z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
z = z.reshape(xx.shape)
plt.pcolormesh(xx, yy, z, cmap=plt.cm.get_cmap('Pastel1'))
plt.scatter(X[:,0], X[:, 1], c = y, cmap=plt.cm.get_cmap('spring'), edgecolors='k')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:KNN")

#把新的数据点用红五星表示
newpoint = [6.75, 4.82]
plt.scatter(newpoint[0],newpoint[1], marker='*', c='red', s=200)
#对新数据点分类进行判断
print('\n\n\n')
print('===============================================')
print('新数据点分类是:',clf.predict([newpoint]))
print('模型正确率:',clf.score(X,y))
print('===============================================')
print('\n\n\n')
#plt.show()
# Out:
# ===============================================
# 新数据点分类是: [1]
# 模型正确率: 0.956
# ===============================================

# %% [markdown]
# # 3.2.3K最近邻算法用于回归分析

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
# %matplotlib inline
#导入数据集,生成特征数量为1，噪音为50的数据集
X, y = datasets.make_regression(n_samples=100, n_features=1, n_informative=1, noise=50, random_state=8)
#用三点图可视化数据
plt.scatter(X, y, c='orange', edgecolors='k')
plt.show()

# %%
#导入用于回归分析的knn模型
from sklearn.neighbors import KNeighborsRegressor
import numpy as np
reg = KNeighborsRegressor()
#用knn模型拟合数据
reg.fit(X, y)
#把预测结果用图像可视化
z = np.linspace(-3, 3, 200).reshape(-1, 1)
print("z.shape=",z.shape)
print("reg.predict(z).shape=",reg.predict(z).shape)
plt.scatter(X, y, c='orange', edgecolors='k')
plt.plot(z, reg.predict(z), c='b', linewidth=3)
plt.title('KNN Regressor')
print('===============================================')
print('模型评分{:.2f}:'.format(reg.score(X,y)))
print('===============================================')
plt.show()
# Out:
# z.shape= (200, 1)
# reg.predict(z).shape= (200,)
# ===============================================
# 模型评分0.77:
# ===============================================

# %% [markdown]
# # 修改最近邻k值k默认为5，改为k=2

# %%
#修改最近邻k值
reg = KNeighborsRegressor(n_neighbors=2)
#用knn模型拟合数据
reg.fit(X, y)
#把预测结果用图像可视化
z = np.linspace(-3, 3, 200).reshape(-1, 1)
plt.scatter(X, y, c='orange', edgecolors='k')
plt.plot(z, reg.predict(z), c='b', linewidth=3)
plt.title('KNN Regressor')
print('===============================================')
print('模型评分{:.2f}:'.format(reg.score(X,y)))
print('===============================================')
plt.show()
# Out:
# ===============================================
# 模型评分0.86:
# ===============================================

# %% [markdown]
# # 3.3K最近邻算法项目实战--酒的分类

# %%
from sklearn.datasets import load_wine
wine_dataset = load_wine()
X = wine_dataset.data[:,:2]
y = wine_dataset.target
#3.3.1打印酒数据中的键
print("酒数据集中的键:{}".format(wine_dataset.keys()))
print("目标分类名称：",wine_dataset["target_names"])
print("样本数据量：",wine_dataset["data"].shape)
print("样本特征数量:",len(wine_dataset["feature_names"]),"\n特征：{}".format(wine_dataset["feature_names"]))
# Out:
# 酒数据集中的键:dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])
# 目标分类名称： ['class_0' 'class_1' 'class_2']
# 样本数据量： (178, 13)
# 样本特征数量: 13
# 特征：['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']

# %%
#3.3.2生成训练数据和测试数据
#导入数据拆分工具
from sklearn.model_selection import train_test_split
from matplotlib.colors import ListedColormap
#通过固定random_state=0保证每次拆分的数据相同
X_train, X_test, y_train, y_test = train_test_split(wine_dataset['data'], wine_dataset['target'], random_state=0)
print("==========================")
print("X_train shape:{}".format(X_train.shape))
print("X_test shape:{}".format(X_test.shape))
print("y_train shape:{}".format(y_train.shape))
print("y_test shape:{}".format(y_test.shape))
print("==========================")
# Out:
# ==========================
# X_train shape:(133, 13)
# X_test shape:(45, 13)
# y_train shape:(133,)
# y_test shape:(45,)
# ==========================

# %%
#3.3.3使用最近邻算法进行建模
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
#训练数据
knn.fit(X_train, y_train)
print(knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
#3.3.4使用模型对新样本的分类进行预测,得分越高说明预测分类越准确
score = knn.score(X_test, y_test)
print("测试数据集得分:{:.2f}".format(score))
print("训练数据集得分:{:.2f}".format(knn.score(X_train, y_train)))
# Out:
# 测试数据集得分:0.76
# 训练数据集得分:1.00

# %%
#定义图像中分区的颜色和散点的颜色
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

#分别用样本的两个特征值创建图像和横轴和纵轴
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

#给每个分类中的样本分配不同的颜色
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
#用散点把样本表示出来
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:(k = 15, weights = 'distance')")
plt.scatter(13.2, 2.77, marker='*', s=80)

plt.show()

# %%
#对新实际数据进行预测
X_new = np.array([[13.2, 2.77, 2.51, 18.5, 96.6, 1.04, 2.55, 0.57, 1.47, 6.2, 1.05, 3.33, 820]])
#使用predict进行预测
prediction = knn.predict(X_new)
print(prediction)
# Out:
# [2]
